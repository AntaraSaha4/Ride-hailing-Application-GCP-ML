# %%
import base64
import requests

# %%
with open("./test_dataset/the_cooper_union_the_juilliard_school.wav", "rb") as f:
    speech = f.read()
    speech_data = str(base64.b64encode(speech).decode("utf-8"))
    endpoint = "http://localhost:5000"
    
    response = requests.post('{}/farePrediction'.format(endpoint), data=speech_data)
    print(response.json())
# Out:
# {'predicted_fare': '14.75', 'entities': ['Cooper Union', 'Juilliard School'], 'text': 'Your expected fare from Cooper Union to Juilliard School is $14.75', 'speech': '...'}

# %%
# Sppech To Text
with open("./test_dataset/the_cooper_union_the_juilliard_school.wav", "rb") as f:
    speech = f.read()
    speech_data = str(base64.b64encode(speech).decode("utf-8"))
    endpoint = "http://localhost:5000"
    
    response_text = requests.post('{}/speechToText'.format(endpoint), data=speech_data)
    test_entities = response_text.json().get('text')

    response_entities = requests.get('{}/namedEntities'.format(endpoint), params={'text': test_entities})
    origin = response_entities.json().get('entities')[0]
    destination = response_entities.json().get('entities')[1]

    response_dir = requests.get('{}/directions'.format(endpoint), params={'origin': origin, 'destination': destination})

    print(response_dir.json())
# Out:
# {'start_location': {'lng': -73.99116719999999, 'lat': 40.72792270000001}, 'end_location': {'lng': -73.9834602, 'lat': 40.7735666}}

# %%
response_dir.json()["start_location"]["lng"]
# Out:
# -73.99116719999999

# %%
with open("./test_dataset/katzs_delicatessen.jpg", 'rb') as f:
    ori = f.read()
with open("./test_dataset/bamonte.jpg", 'rb') as f:
    dest = f.read()
#endpoint = "https://ml-fare-prediction-120818.ue.r.appspot.com"
endpoint = "http://localhost:5000"
vision_ori_data = str(base64.b64encode(ori).decode("utf-8"))
vision_dest_data = str(base64.b64encode(dest).decode("utf-8"))
response = requests.post('{}/farePredictionVision'.format(endpoint), data={'source': vision_ori_data,'destination': vision_dest_data})

# %%
response.text
# Out:
# '{"predicted_fare": "10.50", "entities": ["Katz\'s Delicatessen", "Bamonte\'s"], "text": "Your expected fare from Katz\'s Delicatessen to Bamonte\'s is $10.50", "speech": "..."}'
